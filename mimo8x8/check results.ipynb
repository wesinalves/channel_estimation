# %%
import numpy as np
import pandas as pd
from scipy.io import savemat, loadmat
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv('1-bit\\all_nmse_conv_256samples_-11_Nr8_Nt8_60GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))

# %%
dataset
# Out:
#         -21       -18       -15        -12        -9         -6         -3   \
# 0 -1.962867 -3.035799 -4.247630  -5.833898  -8.004822 -10.013758 -11.979592
# 1 -6.146225 -7.081030 -7.794053 -10.924432 -12.258470 -15.420013 -17.639900
# 2  0.048733 -0.538342 -1.414341  -2.206812  -2.833517  -4.407407  -4.375932
#
#           0          3          6          9          12         15  \
# 0 -13.604137 -15.547994 -15.481265 -16.319732 -16.075700 -17.807181
# 1 -20.270990 -23.020520 -24.677327 -25.827864 -26.363544 -27.117524
# 2  -5.232240  -7.303063  -6.631597  -6.841078  -6.545019  -6.058077
#
#           18         21
# 0 -17.644229 -17.599978
# 1 -26.977615 -27.192937
# 2  -7.492375  -8.628828

# %%
dataset.loc[0,:].plot(style='--', label='avg')
dataset.loc[1,:].plot(style='s', label='min')
dataset.loc[2,:].plot(style='o', label='max')
plt.legend()

# %%
dataset3Ghz = pd.read_csv('all_nmse_hq_dense_-11_Nr8_Nt8_3GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
dataset5Ghz = pd.read_csv('all_nmse_hq_dense_-11_Nr8_Nt8_5GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
dataset60Ghz = pd.read_csv('1-bit\\all_nmse_conv_256samples_-11_Nr8_Nt8_60GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
dataset60Ghz_mob = pd.read_csv('all_nmse_hq_dense_-11_Nr8_Nt8_60GHz_mob.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
randomized = pd.read_csv('all_nmse_hq_dense_256samples_-11_Nr8_Nt8_randomized.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))

# %%
dataset3Ghz.loc[0,:].plot(style='--', label='2.8GHz')
dataset5Ghz.loc[0,:].plot(style='--', label='5GHz')
dataset60Ghz.loc[0,:].plot(style='--', label='conv 60GHz')
dataset60Ghz_mob.loc[0,:].plot(style='--', label='60GHz mob')
randomized.loc[0,:].plot(style='--', label='Random sparse')
plt.xlabel("SNRdB")
plt.ylabel("nmse avg")
plt.title("1-bit MIMO with histeresys - Dense Architecture")
plt.legend()

# %%
num_samples = [10, 20, 50, 60, 100, 150, 200, 220, 240]
for s in num_samples:
    x = pd.read_csv(f'all_nmse_hq_dense_{s}samples_-11_Nr8_Nt8_60GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
    x.loc[0,:].plot(style='--', label= str(s) + 'samples')

x = pd.read_csv('all_nmse_hq_dense_-11_Nr8_Nt8_60GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
x.loc[0,:].plot(style='--', label='256 samples')

plt.xlabel("SNRdB")
plt.ylabel("nmse avg")
plt.title("1-bit MIMO 60GHz with hist - Dense Architecture")
plt.legend()

# %% [markdown]
# # no histeresys

# %%
dataset3Ghz = pd.read_csv('all_nmse_dense_256samples_-11_Nr8_Nt8_3GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
dataset5Ghz = pd.read_csv('all_nmse_dense_256samples_-11_Nr8_Nt8_5GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
dataset60Ghz = pd.read_csv('all_nmse_dense_256samples_-11_Nr8_Nt8_60GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
dataset60Ghz_mob = pd.read_csv('all_nmse_dense_256samples_-11_Nr8_Nt8_60GHz_mob.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
randomized = pd.read_csv('all_nmse_dense_256samples_-11_Nr8_Nt8_randomized.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))

# %%
dataset3Ghz.loc[0,:].plot(style='--', label='2.8GHz')
dataset5Ghz.loc[0,:].plot(style='--', label='5GHz')
dataset60Ghz.loc[0,:].plot(style='--', label='60GHz')
dataset60Ghz_mob.loc[0,:].plot(style='--', label='60GHz mob')
randomized.loc[0,:].plot(style='--', label='Random sparse')
plt.xlabel("SNRdB")
plt.ylabel("nmse avg")
plt.title("1-bit MIMO no histeresys - Dense Architecture")
plt.legend()

# %% [markdown]
# # no quantize

# %%
dataset3Ghz = pd.read_csv('all_nmse_dense_noquant_256samples_-11_Nr8_Nt8_3GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
dataset5Ghz = pd.read_csv('all_nmse_dense_noquant_256samples_-11_Nr8_Nt8_5GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
dataset60Ghz = pd.read_csv('all_nmse_dense_noquant_256samples_-11_Nr8_Nt8_60GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
dataset60Ghz_mob = pd.read_csv('all_nmse_dense_noquant_256samples_-11_Nr8_Nt8_60GHz_mob.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
randomized = pd.read_csv('all_nmse_dense_noquant_256samples_-11_Nr8_Nt8_randomized.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))

# %%
dataset3Ghz.loc[0,:].plot(style='--', label='2.8GHz')
dataset5Ghz.loc[0,:].plot(style='--', label='5GHz')
dataset60Ghz.loc[0,:].plot(style='--', label='60GHz')
dataset60Ghz_mob.loc[0,:].plot(style='--', label='60GHz mob')
randomized.loc[0,:].plot(style='--', label='Random sparse')
plt.xlabel("SNRdB")
plt.ylabel("nmse avg")
plt.title("MIMO no quantization - Dense Architecture")
plt.legend()

# %%
num_samples = [10, 20, 50, 60, 100, 150, 200, 220, 240, 256]
for s in num_samples:
    x = pd.read_csv(f'all_nmse_dense_noquant_{s}samples_-11_Nr8_Nt8_60GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
    x.loc[0,:].plot(style='--', label= str(s) + 'samples')

plt.xlabel("SNRdB")
plt.ylabel("nmse avg")
plt.title("MIMO 60GHz no quantization - Dense Architecture")
plt.legend(loc='upper left')

# %% [markdown]
# # no norm
# to do
# 1. MIMO no norm
# 2. MIMO 60GHz

# %%
dataset3Ghz = pd.read_csv('all_nmse_dense_nonorm_256samples_-11_Nr8_Nt8_3GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
dataset5Ghz = pd.read_csv('all_nmse_dense_nonorm_256samples_-11_Nr8_Nt8_5GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
dataset60Ghz = pd.read_csv('all_nmse_dense_nonorm_256samples_-11_Nr8_Nt8_60GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
dataset60Ghz_mob = pd.read_csv('all_nmse_dense_nonorm_256samples_-11_Nr8_Nt8_60GHz_mob.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
randomized = pd.read_csv('all_nmse_dense_nonorm_256samples_-11_Nr8_Nt8_randomized.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))

# %%
dataset3Ghz.loc[0,:].plot(style='--', label='2.8GHz')
dataset5Ghz.loc[0,:].plot(style='--', label='5GHz')
dataset60Ghz.loc[0,:].plot(style='--', label='60GHz')
dataset60Ghz_mob.loc[0,:].plot(style='--', label='60GHz mob')
randomized.loc[0,:].plot(style='--', label='Random sparse')
plt.xlabel("SNRdB")
plt.ylabel("nmse avg")
plt.title("MIMO no normalization - Dense Architecture")
plt.legend()

# %%
x = pd.read_csv('all_nmse_-11_Nr8_Nt8_numEx256_test1.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
x.loc[0,:].plot(style='--', label='60GHz mob')
plt.xlabel("SNRdB")
plt.ylabel("nmse avg")
plt.title("MIMO no normalization - Dense Architecture")
plt.legend()

# %% [markdown]
# # 2-bit quantization

# %%
dataset3Ghz = pd.read_csv('2-bit\\all_nmse_dense_256samples_-11_Nr8_Nt8_3GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
dataset5Ghz = pd.read_csv('2-bit\\all_nmse_dense_256samples_-11_Nr8_Nt8_5GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
dataset60Ghz = pd.read_csv('2-bit\\all_nmse_dense_256samples_-11_Nr8_Nt8_60GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
dataset60Ghz_mob = pd.read_csv('2-bit\\all_nmse_dense_256samples_-11_Nr8_Nt8_60GHz_mob.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))

# %%
dataset3Ghz.loc[0,:].plot(style='--', label='2.8GHz')
dataset5Ghz.loc[0,:].plot(style='--', label='5GHz')
dataset60Ghz.loc[0,:].plot(style='--', label='60GHz')
dataset60Ghz_mob.loc[0,:].plot(style='--', label='60GHz mob')
plt.xlabel("SNRdB")
plt.ylabel("nmse avg")
plt.title("2-bit MIMO - Dense Architecture")
plt.legend()

# %% [markdown]
# # 3-bit quantization

# %%
dataset3Ghz = pd.read_csv('3-bit\\all_nmse_dense_256samples_-11_Nr8_Nt8_3GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
dataset5Ghz = pd.read_csv('3-bit\\all_nmse_dense_256samples_-11_Nr8_Nt8_5GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
dataset60Ghz = pd.read_csv('3-bit\\all_nmse_dense_256samples_-11_Nr8_Nt8_60GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
dataset60Ghz_mob = pd.read_csv('3-bit\\all_nmse_dense_256samples_-11_Nr8_Nt8_60GHz_mob.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))

# %%
dataset3Ghz.loc[0,:].plot(style='--', label='2.8GHz')
dataset5Ghz.loc[0,:].plot(style='--', label='5GHz')
dataset60Ghz.loc[0,:].plot(style='--', label='60GHz')
dataset60Ghz_mob.loc[0,:].plot(style='--', label='60GHz mob')
plt.xlabel("SNRdB")
plt.ylabel("nmse avg")
plt.title("3-bit MIMO - Dense Architecture")
plt.legend()

# %% [markdown]
# # 4-bit quantization

# %%
dataset3Ghz = pd.read_csv('4-bit\\all_nmse_dense_256samples_-11_Nr8_Nt8_3GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
dataset5Ghz = pd.read_csv('4-bit\\all_nmse_dense_256samples_-11_Nr8_Nt8_5GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
dataset60Ghz = pd.read_csv('4-bit\\all_nmse_dense_256samples_-11_Nr8_Nt8_60GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
dataset60Ghz_mob = pd.read_csv('4-bit\\all_nmse_dense_256samples_-11_Nr8_Nt8_60GHz_mob.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))

# %%
dataset3Ghz.loc[0,:].plot(style='--', label='2.8GHz')
dataset5Ghz.loc[0,:].plot(style='--', label='5GHz')
dataset60Ghz.loc[0,:].plot(style='--', label='60GHz')
dataset60Ghz_mob.loc[0,:].plot(style='--', label='60GHz mob')
plt.xlabel("SNRdB")
plt.ylabel("nmse avg")
plt.title("4-bit MIMO - Dense Architecture")
plt.legend()

# %% [markdown]
# # 8-bit quantization

# %%
dataset3Ghz = pd.read_csv('8-bit\\all_nmse_dense_256samples_-11_Nr8_Nt8_3GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
dataset5Ghz = pd.read_csv('8-bit\\all_nmse_dense_256samples_-11_Nr8_Nt8_5GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
dataset60Ghz = pd.read_csv('8-bit\\all_nmse_dense_256samples_-11_Nr8_Nt8_60GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
dataset60Ghz_mob = pd.read_csv('8-bit\\all_nmse_dense_256samples_-11_Nr8_Nt8_60GHz_mob.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))

# %%
dataset3Ghz.loc[0,:].plot(style='--', label='2.8GHz')
dataset5Ghz.loc[0,:].plot(style='--', label='5GHz')
dataset60Ghz.loc[0,:].plot(style='--', label='60GHz')
dataset60Ghz_mob.loc[0,:].plot(style='--', label='60GHz mob')
plt.xlabel("SNRdB")
plt.ylabel("nmse avg")
plt.title("8-bit MIMO - Dense Architecture")
plt.legend()

# %% [markdown]
# # see levels of quantization

# %%
#bitc = pd.read_csv('2-bit\\all_nmse_conv1D_256samples_-11_Nr8_Nt8_60GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
bit1 = pd.read_csv('1-bit\\all_nmse_dense_256samples_-11_Nr8_Nt8_60GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
bit2 = pd.read_csv('2-bit\\all_nmse_dense_256samples_-11_Nr8_Nt8_60GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
bit3 = pd.read_csv('3-bit\\all_nmse_dense_256samples_-11_Nr8_Nt8_60GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
bit4 = pd.read_csv('4-bit\\all_nmse_dense_256samples_-11_Nr8_Nt8_60GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
bit8 = pd.read_csv('8-bit\\all_nmse_dense_256samples_-11_Nr8_Nt8_60GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))

# %%
bit1.loc[0,:].plot(style='--', label='1-bit')
#bitc.loc[0,:].plot(style='--', label='2-bit conv')
bit2.loc[0,:].plot(style='--', label='2-bit')
bit3.loc[0,:].plot(style='--', label='3-bit')
bit4.loc[0,:].plot(style='--', label='4-bit')
bit8.loc[0,:].plot(style='--', label='8-bit')
plt.xlabel("SNRdB")
plt.ylabel("nmse avg")
plt.title("N-bit MIMO 60GHz - Dense Architecture")
plt.legend()

# %% [markdown]
# # range [-10,10]

# %%
x = pd.read_csv('8-bit\\all_nmse_dense_range10_256samples_-11_Nr8_Nt8_60GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
x.loc[0,:].plot(style='--', label='60GHz')
plt.xlabel("SNRdB")
plt.ylabel("nmse avg")
plt.title("8-bit MIMO 60GHz [-10, 10]dB - Dense Architecture")
plt.legend()

# %%
dataset3Ghz = pd.read_csv('noquant\\all_nmse_dense_256samples_-11_Nr8_Nt8_3GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
dataset5Ghz = pd.read_csv('noquant\\all_nmse_dense_256samples_-11_Nr8_Nt8_5GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
dataset60Ghz = pd.read_csv('noquant\\all_nmse_dense_256samples_-11_Nr8_Nt8_60GHz.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))
dataset60Ghz_mob = pd.read_csv('noquant\\all_nmse_dense_256samples_-11_Nr8_Nt8_60GHz_mob.txt', sep=" ", header=None, names = np.arange(-21, 22, 3))

# %%
dataset3Ghz.loc[0,:].plot(style='--', label='2.8GHz')
dataset5Ghz.loc[0,:].plot(style='--', label='5GHz')
dataset60Ghz.loc[0,:].plot(style='--', label='60GHz')
dataset60Ghz_mob.loc[0,:].plot(style='--', label='60GHz mob')
plt.xlabel("SNRdB")
plt.ylabel("nmse avg")
plt.title("MIMO no quantization - Dense Architecture")
plt.legend()
